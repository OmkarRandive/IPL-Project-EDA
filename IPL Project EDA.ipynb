# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %%
df=pd.read_csv("IPL_Dataset.csv")

# %%
df
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# ...

# %%
df.head()
# Out:
#    POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1    2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2    3    David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 3    4    Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 4    5    Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
#
#    50  4s  6s
# 0   5  58  23
# 1   4  67  12
# 2   4  52  14
# 3   3  40  16
# 4   4  36  30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     133 non-null    int64
#  1   Player  133 non-null    object
#  2   Mat     133 non-null    int64
#  3   Inns    133 non-null    int64
#  4   NO      133 non-null    int64
#  5   Runs    133 non-null    int64
#  6   HS      133 non-null    object
#  7   Avg     133 non-null    float64
#  8   BF      133 non-null    int64
#  9   SR      133 non-null    float64
#  10  100     133 non-null    int64
#  11  50      133 non-null    int64
#  12  4s      133 non-null    int64
#  13  6s      133 non-null    int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 14.7+ KB

# %%
df.describe()
# Out:
#              POS         Mat        Inns          NO        Runs         Avg  \
# count  133.00000  133.000000  133.000000  133.000000  133.000000  133.000000
# mean    67.00000    9.631579    6.631579    1.616541  139.157895   19.366241
# std     38.53786    4.893523    5.030925    1.550766  167.293103   18.053343
# min      1.00000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%     34.00000    5.000000    2.000000    0.000000   10.000000    6.000000
# 50%     67.00000   10.000000    5.000000    1.000000   59.000000   15.000000
# 75%    100.00000   14.000000   11.000000    2.000000  232.000000   29.900000
# max    133.00000   17.000000   17.000000    7.000000  670.000000  101.000000
#
#                BF          SR         100          50          4s          6s
# count  133.000000  133.000000  133.000000  133.000000  133.000000  133.000000
# mean   105.714286  107.364737    0.037594    0.827068   11.894737    5.518797
# ...

# %%
# What is the maximum number of matches played by an individual player in a season?

# %%
print("Maximum no. of matches played by an individual player : ",np.max(df["Mat"]),"matches")
# Out:
# Maximum no. of matches played by an individual player :  17 matches

# %%
#What is the highest average of a player in a season?
b=max(df["Avg"])

# %%
b
# Out:
# 101.0

# %%
idx=df["Avg"].idxmax()

# %%
value=df.loc[idx,"Player"]

# %%
value
# Out:
# 'Deepak Hooda'

# %%
print("Highest avg. of an individual player is : ",value , b )
# Out:
# Highest avg. of an individual player is :  Deepak Hooda 101.0

# %%
# What is the average number of matches played by a player in a season?

# %%
x=np.mean(df["Mat"])

# %%
y=int(x)

# %%
print("Average number of matches played by a player in a season is : ", y)
# Out:
# Average number of matches played by a player in a season is :  9

# %%
#Please check the correlation between all the features.

# %%
cor=df.corr()

# %%
cor
# Out:
#            POS       Mat      Inns        NO      Runs       Avg        BF  \
# POS   1.000000 -0.556695 -0.916174 -0.386247 -0.896664 -0.746510 -0.891969
# Mat  -0.556695  1.000000  0.728358  0.555261  0.565237  0.306128  0.555102
# Inns -0.916174  0.728358  1.000000  0.464356  0.895914  0.585148  0.889753
# NO   -0.386247  0.555261  0.464356  1.000000  0.308747  0.429888  0.271021
# Runs -0.896664  0.565237  0.895914  0.308747  1.000000  0.687475  0.989948
# Avg  -0.746510  0.306128  0.585148  0.429888  0.687475  1.000000  0.664173
# BF   -0.891969  0.555102  0.889753  0.271021  0.989948  0.664173  1.000000
# SR   -0.730489  0.371328  0.581468  0.415060  0.517678  0.591306  0.474226
# 100  -0.248353  0.128405  0.224328  0.019726  0.382577  0.233726  0.358550
# 50   -0.769577  0.455437  0.755027  0.174184  0.912264  0.638326  0.900547
# 4s   -0.846965  0.522628  0.846749  0.204779  0.959576  0.623643  0.955994
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(cor,cmap="coolwarm",annot=True,fmt=".2f",square=True)
plt.title("Correlation matrix")
plt.show()

# %%
#Check the list of players who has an average greater than 50 as well strike rate above 120.

# %%
x=df.loc[(df["Avg"]>50)&(df["SR"]>120),"Player"].tolist()

# %%
print(x)
# Out:
# ['KL Rahul', 'Ishan Kishan', 'Kieron Pollard', 'Wriddhiman Saha', 'Ruturaj Gaikwad', 'Deepak Hooda', 'Tom Curran']

# %%
#Please check the list of players who has an average greater than 40 and balls faced above 100.

# %%
x=df.loc[(df["Avg"]>40)&(df["BF"]>100),"Player"].tolist()
x
# Out:
# ['KL Rahul',
#  'Shikhar Dhawan',
#  'Ishan Kishan',
#  'Virat Kohli',
#  'AB de Villiers',
#  'Faf du Plessis',
#  'Eoin Morgan',
#  'Kane Williamson',
#  'Chris Gayle',
#  'Ben Stokes',
#  'Kieron Pollard',
#  'Rahul Tewatia',
#  'Ravindra Jadeja',
#  'Wriddhiman Saha',
#  'Ruturaj Gaikwad']

# %%
#Please check the list of players who scored more than 300 runs with an average greater than 45 & strike rate above 130.

# %%
x=df.loc[(df["Runs"]>300)&(df["Avg"]>45)&(df["SR"]>130),"Player"].tolist()
x
# Out:
# ['Ishan Kishan', 'AB de Villiers', 'Kane Williamson']

# %%
#Players who scroed alteast one century in this season.

# %%
x=df.loc[(df["100"]>=1),"Player"].tolist()

# %%
x
# Out:
# ['KL Rahul', 'Shikhar Dhawan', 'Mayank Agarwal', 'Ben Stokes']

# %%
#Players who scored atleast 4 half centuries in this season.

# %%
x=df.loc[(df["50"]>=4),"Player"].tolist()

# %%
x
# Out:
# ['KL Rahul',
#  'Shikhar Dhawan',
#  'David Warner',
#  'Ishan Kishan',
#  'Quinton de Kock',
#  'Suryakumar Yadav',
#  'Devdutt Padikkal',
#  'AB de Villiers',
#  'Faf du Plessis']

# %%
#Check the list of players who hit more than 45 boundARIES and more than 10 sixes in this season.

# %%
x=df.loc[(df["4s"]>45)&(df["6s"]>10),"Player"].tolist()

# %%
x
# Out:
# ['KL Rahul',
#  'Shikhar Dhawan',
#  'David Warner',
#  'Quinton de Kock',
#  'Suryakumar Yadav']

# %%
# Plot a histogram of number of matches played in a season by players.

# %%
plt.figure(figsize=(20,10))
plt.hist(df["Mat"],bins=15)
plt.xlabel("Matches played")
plt.ylabel("Number of players")
plt.title("Number of matches played by a player in a season.")
# Out:
# Text(0.5, 1.0, 'Number of matches played by a player in a season.')

# %%
#Plot the histogram of balls faced by players.

# %%
plt.figure(figsize=(15,10))
plt.hist(df["BF"],bins=15)
plt.xlabel("Balls Faced")
plt.ylabel("Number of players")
plt.title("Balls faced by players")
# Out:
# Text(0.5, 1.0, 'Balls faced by players')

# %%
#Top 30 players with most runs in a season v/s matches played.

# %%
player_stats=df.groupby("Player")["Runs","Mat"].sum()
top_players=player_stats.sort_values(by="Runs",ascending=False)[:30]
print(top_players)
# Out:
#                   Runs  Mat
# Player
# KL Rahul           670   14
# Shikhar Dhawan     618   17
# David Warner       548   16
# Shreyas Iyer       519   17
# Ishan Kishan       516   14
# Quinton de Kock    503   16
# Suryakumar Yadav   480   16
# Devdutt Padikkal   473   15
# Virat Kohli        466   15
# AB de Villiers     454   15
# Faf du Plessis     449   13
# Shubman Gill       440   14
# Manish Pandey      425   16
# Mayank Agarwal     424   11
# Eoin Morgan        418   14
# Sanju Samson       375   14
# Ambati Rayudu      359   12
# Nicholas Pooran    353   14
# Marcus Stoinis     352   17
# Nitish Rana        352   14
# Jonny Bairstow     345   11
# Rishabh Pant       343   14
# Rohit Sharma       332   12
# Jos Buttler        328   13
# Kane Williamson    317   12
# Steve Smith        311   14
# Shane Watson       299   11
# Chris Gayle        288    7
# Ben Stokes         285    8
# Hardik Pandya      281   14

# %%
#Bar chart for top 20 players with best strike rate in a season.

# %%
top_players=df.sort_values(by ="SR",ascending=False).head(20)
plt.figure(figsize=(20,15))
plt.xlabel("Players")
plt.ylabel("Best strike rate")
plt.xticks(rotation=90)
plt.bar(top_20["Player"],top_20["SR"])
plt.show()

# %%
top_players
# Out:
#      POS               Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  \
# 31    32       Kieron Pollard   16    12   7   268  60*  53.60  140  191.42
# 50    51         Jofra Archer   14    10   4   113  27*  18.83   63  179.36
# 29    30        Hardik Pandya   14    13   5   281  60*  35.12  157  178.98
# 83    84     Tushar Deshpande    5     2   1    21  20*  21.00   12  175.00
# 33    34      Ravindra Jadeja   14    11   6   232   50  46.40  135  171.85
# 53    54          Abdul Samad   12     8   3   111   33  22.20   65  170.76
# 17    18      Nicholas Pooran   14    14   4   353   77  35.30  208  169.71
# 81    82  Nathan Coulter-Nile    7     2   1    25  24*  25.00   15  166.66
# 110  111       Jasprit Bumrah   15     1   1     5   5*   0.00    3  166.66
# 74    75         Chris Morris    9     5   1    34  25*   8.50   21  161.90
# 15    16         Sanju Samson   14    14   1   375   85  28.84  236  158.89
# ...

# %%
#Top 30 players with highest number of sixes.

# %%
highest_6s=df.groupby("Player")["Mat","6s"].sum()
sorting=highest_6s.sort_values(by="6s",ascending=False).head(30)
sorting
# Out:
#                   Mat  6s
# Player
# Ishan Kishan       14  30
# Sanju Samson       14  26
# Hardik Pandya      14  25
# Nicholas Pooran    14  25
# Eoin Morgan        14  24
# AB de Villiers     15  23
# KL Rahul           14  23
# Chris Gayle         7  23
# Quinton de Kock    16  22
# Kieron Pollard     16  22
# Rohit Sharma       12  19
# Manish Pandey      16  18
# Rahul Tewatia      14  17
# Jos Buttler        13  16
# Shreyas Iyer       17  16
# Marcus Stoinis     17  16
# Mayank Agarwal     11  15
# David Warner       16  14
# Faf du Plessis     13  14
# Shane Watson       11  13
# Jonny Bairstow     11  13
# Shimron Hetmyer    12  12
# Shikhar Dhawan     17  12
# Nitish Rana        14  12
# Ambati Rayudu      12  12
# Sam Curran         14  12
# Suryakumar Yadav   16  11
# Ravindra Jadeja    14  11
# Virat Kohli        15  11
# Rahul Tripathi     11  10

# %%
#Scatter plot of runs scored by a player v/s balls faced in a season.

# %%
plt.figure(figsize=(10,5))
plt.scatter(df["Runs"],df["BF"],cmap="coolwarm")
sns.regplot(x=df["Runs"],y=df["BF"])
plt.xlabel("Runs scored")
plt.ylabel("Balls Faced")
plt.title("Runs scored vs balls faced")
plt.show()

# %%
#KDE plot for averages on a season.

# %%
sns.kdeplot(data=df,x="Avg")
plt.title("KDE plot of average")
# Out:
# Text(0.5, 1.0, 'KDE plot of average')
